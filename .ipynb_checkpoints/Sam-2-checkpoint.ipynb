# %%
# start by importing the modules we will need
import requests
import json  #we will use these later in retrieving geodata and plotting university locations using openstreetmaps
import folium
import numpy as np
import cufflinks as cf
import pandas as pd #These allow us to open our data in a pandas data frame
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display
print("Ready to go to college?".title())
# Out:
# Ready To Go To College?

# %%
import sys
from sys import exit

help(exit)
# Out:
# Help on built-in function exit in module sys:
#
# exit(...)
#     exit([status])
#
#     Exit the interpreter by raising SystemExit(status).
#     If the status is omitted or None, it defaults to zero (i.e., success).
#     If the status is an integer, it will be used as the system exit status.
#     If it is another kind of object, it will be printed and the system
#     exit status will be one (i.e., failure).

# %%
accepted_states = ['Alabama','Alaska','Arizona','Arkansas' ,'California' ,'Colorado','Connecticut', 'Delaware','Florida','Georgia']
state = input('Enter State: ex. NewYork ')
try:
    state = pd.read_csv(state)
except FileNotFoundError:
    print('Please re-run and follow the correct format. Enter the state in title format. If the state has two words, ignore the space.')
    print("For example: Connecticut, NewYork, NewJersey, etc.")
    try:
        state = input('Enter State: ex. NewYork ')
        state = pd.read_csv(state)
    except FileNotFoundError:
        exit(0)
    

    #while True:
        #state = input('Enter State: ex. NewYork ')
        #if state is not in accepted_states:
            #break
        #else:
            #state = pd.read_csv(state)
#Add column based on size
state['size'] = np.nan
state['size'][state['Student population']>15000] = 'large'
state['size'][state['Student population']<=15000] = 'medium'
state['size'][state['Student population'] <=5000] = 'small'
state

display(state)
#filter by type of institution
college_types = list(state['Type'].value_counts().index)
i = 1
for types in college_types:
    print(i,types)
    i = i + 1
choice = input ('What type of university are you interested in? Enter the correspondong number (1 - 6). If you have no preference, just hit enter. ')
try:
    if choice == '':
        state2 = state
    else:
        choice = int(choice)#convert choice into an integer that corresponds to the menu options
        choice_value = college_types[choice-1]
        state2 = state[state['Type']==choice_value]
    display(state2)
except ValueError:
        print("I am assuming you do not have a preference then. I guess we'll continue.")

#filter by surrounding area
surrounding_area = list(state2['Campus setting'].value_counts().index)
i = 1
for types in surrounding_area:
    print(i,types)
    i = i + 1
area = input ('What setting would you like the campus to be in? Please choose from the menu by entering the corresponding number or press enter if you have no preference.')
if area == '':
    state3 = state2
else:
    area = int(area)
    setting_preference = surrounding_area[area-1]
    state3 = state2[state2['Campus setting']==setting_preference]
display(state3)

#filter by size
college_sizes = list(state3['size'].value_counts().index)
i = 1
for types in college_sizes:
    print(i,types)
    i = i + 1
size_preference = input("How big do you want your university to be? Above are your options. Press enter if you have no preference.")
if size_preference == '':
    state4 = state3
else:
    size_preference= int(size_preference) 
    size = college_sizes[size_preference -1]
    state4=state3[state3['size']==size]
display(state4)

#filter by on campus housing
campus_housing = input('Do you want campus housing? Yes or no or press enter if you do not have a preference')
campus_housing = campus_housing.capitalize()
print(campus_housing)
if campus_housing == 'Yes':
    state5 = state4[state4['Campus housing'] == 'Yes']
    display(state5)

elif campus_housing == 'No':
    state5 = state4[state4['Campus housing'] == 'No']
    display(state5)
else: 
    state5 = state4
    display(state5)
# Out:
# Enter State: ex. NewYork no
# 20                    www.artinstitutes.edu/san-diego/
# 21                www.artinstitutes.edu/san-francisco/
# 22                                   www.artcenter.edu
# 23                                     www.ashford.edu
# 24                                         www.apu.edu
# 25                     www.apu.edu/university-college/
# 26                                     www.berginu.edu
# 27                                         www.buc.edu
# 28                                        www.bhdi.edu
# 29                               https://www.biola.edu
# ..                                                 ...
# 180                                      www.ucla.edu/
# 181                                   www.ucmerced.edu
# 182                                        WWW.UCR.EDU
# 183                                       www.ucsd.edu
# 184                                       www.ucsb.edu
# 185                                      www.ucsc.edu/
# 186                                   www.laverne.edu/
# 187                                    www.phoenix.edu
# 188                                   www.redlands.edu
# 189                                   www.sandiego.edu
# 190                              https://www.usfca.edu
# 191                                       www.usc.edu/
# 192                                    www.pacific.edu
# 193                                       uopeople.edu
# 194                                      www.uwest.edu
# 195                                       www.uwla.edu
# 196                           https://www.vanguard.edu
# 197                           westcoastuniversity.edu/
# 198                           westcoastuniversity.edu/
# 199                           westcoastuniversity.edu/
# 200                                 www.westcliff.edu/
# 201                                   www.westmont.edu
# 202                                   www.whittier.edu
# 203                                     WWW.JESSUP.EDU
# 204                                      woodbury.edu/
# 205                                        www.wmu.edu
# 206                                      www.yoec.edu/
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#                                                   Type  \
# 0                           4-year, Private for-profit
# 1                           4-year, Private for-profit
# 2                           4-year, Private for-profit
# 3                       4-year, Private not-for-profit
# 4                       4-year, Private not-for-profit
# 5                           4-year, Private for-profit
# 6    4-year, primarily associate's, Private for-profit
# 7                4-year, primarily associate's, Public
# 8                       4-year, Private not-for-profit
# 9                       4-year, Private not-for-profit
# 10                          4-year, Private for-profit
# 11                          4-year, Private for-profit
# 12                          4-year, Private for-profit
# 13                          4-year, Private for-profit
# 14                          4-year, Private for-profit
# 15                          4-year, Private for-profit
# 16   4-year, primarily associate's, Private for-profit
# 17                          4-year, Private for-profit
# 18                          4-year, Private for-profit
# 19                          4-year, Private for-profit
# 20                          4-year, Private for-profit
# 21                          4-year, Private for-profit
# 22                      4-year, Private not-for-profit
# 23                          4-year, Private for-profit
# 24                      4-year, Private not-for-profit
# 25                      4-year, Private not-for-profit
# 26                      4-year, Private not-for-profit
# 27                      4-year, Private not-for-profit
# 28   4-year, primarily associate's, Private for-profit
# 29                      4-year, Private not-for-profit
# ..                                                 ...
# 180                                     4-year, Public
# 181                                     4-year, Public
# 182                                     4-year, Public
# 183                                     4-year, Public
# 184                                     4-year, Public
# 185                                     4-year, Public
# 186                     4-year, Private not-for-profit
# 187                         4-year, Private for-profit
# 188                     4-year, Private not-for-profit
# 189                     4-year, Private not-for-profit
# 190                     4-year, Private not-for-profit
# 191                     4-year, Private not-for-profit
# 192                     4-year, Private not-for-profit
# 193  4-year, primarily associate's, Private not-for...
# 194                     4-year, Private not-for-profit
# 195                         4-year, Private for-profit
# 196                     4-year, Private not-for-profit
# 197                         4-year, Private for-profit
# 198                         4-year, Private for-profit
# 199                         4-year, Private for-profit
# 200                         4-year, Private for-profit
# 201                     4-year, Private not-for-profit
# 202                     4-year, Private not-for-profit
# 203                     4-year, Private not-for-profit
# 204                     4-year, Private not-for-profit
# 205                     4-year, Private not-for-profit
# 206                     4-year, Private not-for-profit
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#                                         Awards offered   Campus setting  \
# 0    Less than one year certificate|One but less th...      City: Large
# 1    Associate's degree|Two but less than 4 years c...      City: Large
# 2    Less than one year certificate|One but less th...      City: Large
# 3    Bachelor's degree|Master's degree|Doctor's deg...              NaN
# 4                    Bachelor's degree|Master's degree      City: Large
# 5    One but less than two years certificate|Bachel...    Suburb: Large
# 6    Less than one year certificate|One but less th...      City: Large
# 7    Less than one year certificate|One but less th...    Suburb: Large
# 8    Less than one year certificate|Bachelor's degr...    Suburb: Large
# 9    Bachelor's degree|Postbaccalaureate certificat...      City: Small
# 10   Associate's degree|Bachelor's degree|Master's ...    City: Midsize
# 11   Associate's degree|Bachelor's degree|Master's ...    Suburb: Large
# 12   Associate's degree|Bachelor's degree|Master's ...    Suburb: Large
# 13   Associate's degree|Bachelor's degree|Master's ...      City: Large
# 14   Associate's degree|Bachelor's degree|Master's ...    Suburb: Large
# 15   One but less than two years certificate|Associ...      City: Large
# 16   One but less than two years certificate|Associ...    City: Midsize
# 17   One but less than two years certificate|Associ...      City: Small
# 18   One but less than two years certificate|Associ...      City: Large
# 19   One but less than two years certificate|Associ...      City: Large
# 20   One but less than two years certificate|Associ...      City: Large
# 21   One but less than two years certificate|Associ...      City: Large
# 22                   Bachelor's degree|Master's degree    City: Midsize
# 23   Associate's degree|Bachelor's degree|Master's ...      City: Large
# 24   Less than one year certificate|Bachelor's degr...    Suburb: Large
# 25   Less than one year certificate|Associate's deg...    Suburb: Large
# 26   Associate's degree|Bachelor's degree|Master's ...    Suburb: Large
# 27   Less than one year certificate|Two but less th...      City: Large
# 28                Associate's degree|Bachelor's degree    Suburb: Large
# 29   Bachelor's degree|Postbaccalaureate certificat...    Suburb: Large
# ..                                                 ...              ...
# 180  Bachelor's degree|Master's degree|Doctor's deg...      City: Large
# 181  Bachelor's degree|Master's degree|Doctor's deg...    Rural: Fringe
# 182  Bachelor's degree|Master's degree|Doctor's deg...      City: Large
# 183  Bachelor's degree|Master's degree|Doctor's deg...      City: Large
# 184  Bachelor's degree|Postbaccalaureate certificat...  Suburb: Midsize
# 185  Bachelor's degree|Postbaccalaureate certificat...      City: Small
# 186  Less than one year certificate|One but less th...    Suburb: Large
# 187  Less than one year certificate|Associate's deg...    City: Midsize
# 188  Less than one year certificate|One but less th...      City: Small
# 189  Bachelor's degree|Postbaccalaureate certificat...      City: Large
# 190  Bachelor's degree|Postbaccalaureate certificat...      City: Large
# 191  Bachelor's degree|Postbaccalaureate certificat...      City: Large
# 192  Bachelor's degree|Master's degree|Doctor's deg...      City: Large
# 193  Associate's degree|Bachelor's degree|Master's ...    City: Midsize
# 194  One but less than two years certificate|Bachel...    Suburb: Large
# 195  Master's degree|Doctor's degree - professional...    Suburb: Large
# 196  Less than one year certificate|Associate's deg...    City: Midsize
# 197                                  Bachelor's degree      City: Large
# 198                                  Bachelor's degree    City: Midsize
# 199  Bachelor's degree|Master's degree|Post-master'...      City: Large
# 200  Less than one year certificate|Bachelor's degr...              NaN
# 201  One but less than two years certificate|Bachel...  Suburb: Midsize
# 202  Bachelor's degree|Master's degree|Doctor's deg...    Suburb: Large
# 203  One but less than two years certificate|Associ...    Rural: Fringe
# 204                  Bachelor's degree|Master's degree      City: Large
# 205  Less than one year certificate|Bachelor's degr...      City: Large
# 206                                  Bachelor's degree      City: Large
# 207                                                NaN              NaN
# 208                                                NaN              NaN
# 209                                                NaN              NaN
#
#     Campus housing  Student population  Undergraduate students  \
# 0               No               164.0                    25.0
# 1              Yes             12608.0                  8303.0
# 2               No              4003.0                  1471.0
# 3               No                 NaN                     NaN
# 4              Yes               159.0                    65.0
# 5               No               262.0                   261.0
# 6               No               167.0                   167.0
# 7               No             14105.0                 14105.0
# 8               No               736.0                   198.0
# 9               No               329.0                   128.0
# 10              No               495.0                   304.0
# 11              No               475.0                   282.0
# 12              No               472.0                   157.0
# 13              No               297.0                   169.0
# 14              No               304.0                   111.0
# 15             Yes              1096.0                  1096.0
# 16             Yes              1100.0                  1100.0
# 17              No               398.0                   398.0
# 18             Yes               771.0                   771.0
# 19              No               529.0                   529.0
# 20             Yes              1119.0                  1119.0
# 21             Yes               630.0                   630.0
# 22              No              2138.0                  1908.0
# 23              No             41361.0                 35870.0
# 24             Yes             10020.0                  5770.0
# 25              No              1610.0                  1365.0
# 26              No                82.0                    42.0
# 27              No               402.0                   293.0
# 28              No                25.0                    25.0
# 29             Yes              6095.0                  4091.0
# ..             ...                 ...                     ...
# 180            Yes             43548.0                 30873.0
# 181            Yes              7336.0                  6815.0
# 182            Yes             22715.0                 19799.0
# 183            Yes             34979.0                 28127.0
# 184            Yes             24346.0                 21574.0
# 185            Yes             18783.0                 16962.0
# 186            Yes              8369.0                  5459.0
# 187             No             13336.0                 11035.0
# 188            Yes              5071.0                  3237.0
# 189            Yes              8508.0                  5711.0
# 190            Yes             11003.0                  6745.0
# 191            Yes             43871.0                 18794.0
# 192            Yes              6128.0                  3483.0
# 193             No              4411.0                  4390.0
# 194            Yes               324.0                   158.0
# 195             No               207.0                     NaN
# 196            Yes              2104.0                  1791.0
# 197             No              1558.0                  1558.0
# 198             No              1210.0                  1210.0
# 199             No              2156.0                  1870.0
# 200             No                 NaN                     NaN
# 201            Yes              1277.0                  1277.0
# 202            Yes              2072.0                  1614.0
# 203            Yes              1318.0                  1165.0
# 204            Yes              1283.0                  1104.0
# 205             No               339.0                   133.0
# 206            Yes               151.0                   151.0
# 207            NaN                 NaN                     NaN
# 208            NaN                 NaN                     NaN
# 209            NaN                 NaN                     NaN
#
#     Graduation Rate Transfer-Out Rate Cohort Year * Net Price **  \
# 0               NaN               NaN     Fall 2010          NaN
# 1               37%               18%     Fall 2010      $29,301
# 2               NaN               NaN     Fall 2010      $19,190
# 3               NaN               NaN     Fall 2016          NaN
# 4               44%               NaN     Fall 2010      $28,389
# 5              100%               NaN     Fall 2010      $18,079
# 6               62%               NaN     Fall 2010      $11,103
# 7               29%               14%     Fall 2010       $4,646
# 8               NaN               NaN     Fall 2010          NaN
# 9               NaN               NaN     Fall 2010          NaN
# 10               0%               NaN     Fall 2010      $21,132
# 11              25%               25%     Fall 2010      $21,327
# 12              33%               NaN     Fall 2010      $25,040
# 13               9%               NaN     Fall 2010      $20,749
# 14               0%               NaN     Fall 2010          NaN
# 15              30%               NaN     Fall 2010      $28,044
# 16              34%                2%     Fall 2010      $21,426
# 17              39%                2%     Fall 2010          NaN
# 18              35%                4%     Fall 2010      $23,872
# 19              36%               NaN     Fall 2010      $23,065
# 20              42%                4%     Fall 2010      $24,168
# 21              31%                1%     Fall 2010      $22,560
# 22              73%               NaN     Fall 2010      $43,814
# 23              17%               NaN     Fall 2010      $18,235
# 24              70%               22%     Fall 2010      $28,506
# 25              NaN               NaN     Fall 2010      $22,318
# 26              NaN               NaN     Fall 2010          NaN
# 27              41%               16%     Fall 2010      $10,012
# 28             100%               NaN     Fall 2010          NaN
# 29              72%               NaN     Fall 2010      $32,273
# ..              ...               ...           ...          ...
# 180             91%                2%     Fall 2010      $14,236
# 181             66%               NaN     Fall 2010      $12,805
# 182             73%               19%     Fall 2010      $12,841
# 183             87%               NaN     Fall 2010      $14,770
# 184             82%               NaN     Fall 2010      $15,149
# 185             77%                5%     Fall 2010      $16,261
# 186             66%               NaN     Fall 2010      $22,284
# 187             18%               NaN     Fall 2010      $18,059
# 188             74%               NaN     Fall 2010      $34,200
# 189             78%               NaN     Fall 2010      $38,596
# 190             72%               17%     Fall 2010      $35,054
# 191             92%               NaN     Fall 2010      $32,932
# 192             68%               NaN     Fall 2010      $33,794
# 193              4%               NaN     Fall 2010       $2,138
# 194             50%               50%     Fall 2010      $12,474
# 195             NaN               NaN     Fall 2010          NaN
# 196             56%               NaN     Fall 2010      $21,827
# 197             62%               NaN     Fall 2010      $45,144
# 198             50%               NaN     Fall 2010      $42,809
# 199             73%               NaN     Fall 2010      $47,233
# 200             NaN               NaN     Fall 2016          NaN
# 201             77%               NaN     Fall 2010      $34,974
# 202             64%               NaN     Fall 2010      $25,638
# 203             65%               NaN     Fall 2010      $22,263
# 204             44%               NaN     Fall 2010      $30,399
# 205              0%               25%     Fall 2010      $14,990
# 206             33%               42%     Fall 2010      $12,747
# 207             NaN               NaN           NaN          NaN
# 208             NaN               NaN           NaN          NaN
# 209             NaN               NaN           NaN          NaN
#
#                          Largest Program  IPEDS ID      OPE ID    size
# 0                 Legal Studies, General  488031.0   4243800.0   small
# 1                                      -  108232.0    753100.0  medium
# 2                                      -  110468.0   1111700.0   small
# 3                                      -  490081.0   4227100.0     NaN
# 4                                      -  116846.0    274100.0   small
# 5                                      -  433004.0   3225300.0   small
# 6    Massage Therapy/Therapeutic Massage  457299.0   4160400.0   small
# 7                                      -  109350.0    111300.0  medium
# 8                                      -  245838.0    301002.0   small
# 9                                      -  245847.0    301003.0   small
# 10                                     -  450526.0   2179932.0   small
# 11                                     -  447272.0   2179928.0   small
# 12                                     -  436438.0   2179900.0   small
# 13                                     -  450544.0   2179929.0   small
# 14                                     -  121983.0   2179908.0   small
# 15                                     -  410502.0   2179938.0   small
# 16                                     -  448576.0   2179948.0   small
# 17                                     -  432533.0   2179941.0   small
# 18                                     -  441973.0   2179944.0   small
# 19                                     -  450094.0   2179945.0   small
# 20                                     -  117113.0   2179947.0   small
# 21                                     -  117928.0   2179943.0   small
# 22                                     -  109651.0    111600.0   small
# 23                                     -  154022.0    188100.0   large
# 24                                     -  109785.0    111700.0  medium
# 25                                     -  474863.0    111718.0   small
# 26                                     -  461643.0   4176300.0   small
# 27                                     -  110060.0   3266300.0   small
# 28                                     -  475635.0   4185500.0   small
# 29                                     -  110097.0    112200.0  medium
# ..                                   ...       ...         ...     ...
# 180                                    -  110662.0    131500.0   large
# 181                                    -  445188.0   4127100.0  medium
# 182                                    -  110671.0    131600.0   large
# 183                                    -  110680.0    131700.0   large
# 184                                    -  110705.0    132000.0   large
# 185                                    -  110714.0    132100.0   large
# 186                                    -  117140.0    121600.0  medium
# 187                                    -  484631.0  82098842.0  medium
# 188                                    -  121691.0    132200.0  medium
# 189                                    -  122436.0   1039500.0  medium
# 190                                    -  122612.0    132500.0  medium
# 191                                    -  123961.0    132800.0   large
# 192                                    -  120883.0    132900.0  medium
# 193                                    -  488846.0         NaN   small
# 194                                    -  449870.0   3696300.0   small
# 195                                    -  484862.0         NaN   small
# 196                                    -  123651.0    129300.0   small
# 197                                    -  443331.0   3698300.0   small
# 198                                    -  458229.0   3698302.0   small
# 199                                    -  458210.0   3698301.0   small
# 200                                    -  490133.0   4249600.0     NaN
# 201                                    -  125727.0    134100.0   small
# 202                                    -  125763.0    134200.0   small
# 203                                    -  122728.0    128100.0   small
# 204                                    -  125897.0    134300.0   small
# 205                                    -  401223.0   3868300.0   small
# 206                                    -  126076.0   2262400.0   small
# 207                                  NaN       NaN         NaN     NaN
# 208                                  NaN       NaN         NaN     NaN
# 209                                  NaN       NaN         NaN     NaN
#
# [210 rows x 17 columns]
# 1 4-year, Private not-for-profit
# 2 4-year, Private for-profit
# 3 4-year, Public
# 4 4-year, primarily associate's, Private for-profit
# 5 4-year, primarily associate's, Public
# 6 4-year, primarily associate's, Private not-for-profit
# What type of university are you interested in? Enter the correspondong number (1 - 6). If you have no preference, just hit enter. no
# I am assuming you do not have a preference then. I guess we'll continue.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dea42a72b019> in <module>()
#      46
#      47 #filter by surrounding area
# ---> 48 surrounding_area = list(state2['Campus setting'].value_counts().index)
#      49 i = 1
#      50 for types in surrounding_area:
#
# NameError: name 'state2' is not defined

# %%
CENTER_US = (39.8333333,-98.585522)
#london = (51.5074, -0.1278)
map = folium.Map(location=CENTER_US, zoom_start=4)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
school_data= pd.DataFrame({'Name':state4['Name'],
              'Location':state4['Address'],'Website': state4['Website']})
display(school_data)
#list(school_data)

#created a new data frame with the information we want. 



def get_coordinates_using_google(location):
    url = 'http://maps.googleapis.com/maps/api/geocode/json'
    options = { 'address' : location }  
    response = requests.get(url, params = options)            
    geodata = response.json()
    coords = geodata['results'][0]['geometry']['location']
    return coords
try:
    for index, each_school in school_data.iterrows():
        location = each_school['Location']
        coords = get_coordinates_using_google(location)
        name = str(each_school['Name'])
        website = str(each_school['Website'])
        #print(name, website, coords)
        pos = (coords['lat'],coords['lng'])
        message = "%s: %s" % (name,website)
        i=i+1
        marker = folium.CircleMarker(location=pos,
                                    popup=message,
                                    color='#3226cc'
                                    )
        map.add_children(marker)
    map  
except IndexError:
    print("Try re-running me again.")
# Out:
#                                               Location  \
# 6    3440 Wilshire Blvd Ste 310, Los Angeles, Calif...
# 76   919 S Grand Ave, Los Angeles, California 90015...
# 77   55 Stockton St, San Francisco, California 9410...
# 101  6363 Sunset Blvd, Hollywood, California 90028-...
# 110  6752 Hollywood Blvd., Hollywood, California 90028
# 128  6465 Sycamore Canyon Blvd Ste 100, Riverside, ...
# 129  6250 El Cajon Blvd, San Diego, California 9211...
# 147  5300 California Avenue, Bakersfield, Californi...
# 160  525 N. Muller Street, Anaheim, California 9280...
# 164  2041 Business Ctr Dr Ste 107, Irvine, Californ...
# 173  1149 W. 190th St.  Suite 2000, Torrance, Calif...
#
#                                                   Name  \
# 6                                      Angeles College
# 76   FIDM-Fashion Institute of Design & Merchandisi...
# 77   FIDM-Fashion Institute of Design & Merchandisi...
# 101                            Los Angeles Film School
# 110                                Musicians Institute
# 128                            Platt College-Riverside
# 129                            Platt College-San Diego
# 147         Santa Barbara Business College-Bakersfield
# 160        Southern California Institute of Technology
# 164                              Stanbridge University
# 173       Trinity School of Health and Allied Sciences
#
#                      Website
# 6     www.angelescollege.edu
# 76              www.fidm.edu
# 77              WWW.FIDM.EDU
# 101           www.lafilm.edu
# 110               www.mi.edu
# 128     www.plattcollege.edu
# 129            www.platt.edu
# 147           sbbcollege.edu
# 160  https://www.scitech.edu
# 164       www.stanbridge.edu
# 173               tshas.edu/
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def get_coordinates_using_google(location):
    url = 'http://maps.googleapis.com/maps/api/geocode/json'
    options = { 'address' : location }  
    response = requests.get(url, params = options)            
    geodata = response.json()
    coords = geodata['results'][0]['geometry']['location']
    return coords

for index, each_school in state.iterrows():
    location = each_school['Address']
    coords = get_coordinates_using_google(location)
    name = str(each_school['Name'])
    website = str(each_school['Website'])
    #print(name, website, coords)
    pos = (coords['lat'],coords['lng'])
    message = "%s: %s" % (name,website)
    i=i+1
    marker = folium.CircleMarker(location=pos,
                                popup=message,
                                color='#3333cc'
                                )
    map.add_children(marker)
map
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-ecbe323acede> in <module>()
#      11 for index, each_school in state.iterrows():
#      12     location = each_school['Address']
# ---> 13     coords = get_coordinates_using_google(location)
#      14     name = str(each_school['Name'])
#      15     website = str(each_school['Website'])
#
# <ipython-input-21-ecbe323acede> in get_coordinates_using_google(location)
#       6     response = requests.get(url, params = options)
#       7     geodata = response.json()
# ----> 8     coords = geodata['results'][0]['geometry']['location']
#       9     return coords
#      10
#
# IndexError: list index out of range
